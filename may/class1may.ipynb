# %%
import pandas as pd

# %%
t=pd.read_csv('Churn_Modelling.csv')

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
t['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
t['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
t['Geography'].nunique()
# Out:
# 3

# %%
t['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
t.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
#[row,columns]
t.iloc[0:3,0:3]
# Out:
#    RowNumber  CustomerId   Surname
# 0          1    15634602  Hargrave
# 1          2    15647311      Hill
# 2          3    15619304      Onio

# %%
#[0-6rows,3-6columns]
t.iloc[0:6,3:6]
# Out:
#    CreditScore Geography  Gender
# 0          619    France  Female
# 1          608     Spain  Female
# 2          502    France  Female
# 3          699    France  Female
# 4          850     Spain  Female
# 5          645     Spain    Male

# %%
#index seted as rownumber
x=t.set_index('RowNumber')
x
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %%
# iloc sirf integer value lega
x.iloc[1]
# Out:
# CustomerId          15647311
# Surname                 Hill
# CreditScore              608
# Geography              Spain
# Gender                Female
# Age                       41
# Tenure                     1
# Balance             83807.86
# NumOfProducts              1
# HasCrCard                  0
# IsActiveMember             1
# EstimatedSalary    112542.58
# Exited                     0
# Name: 2, dtype: object

# %%
#loc categorical value lega jo index ki value h 
print(x.head())
x.loc[1]
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# ...

# %%
#set surname as index
z=t.set_index('Surname')
z
# Out:
#            RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# Surname
# Hargrave           1    15634602          619    France  Female   42       2
# Hill               2    15647311          608     Spain  Female   41       1
# Onio               3    15619304          502    France  Female   42       8
# Boni               4    15701354          699    France  Female   39       1
# Mitchell           5    15737888          850     Spain  Female   43       2
# ...              ...         ...          ...       ...     ...  ...     ...
# Obijiaku        9996    15606229          771    France    Male   39       5
# Johnstone       9997    15569892          516    France    Male   35      10
# Liu             9998    15584532          709    France  Female   36       7
# Sabbatini       9999    15682355          772   Germany    Male   42       3
# Walker         10000    15628319          792    France  Female   28       4
#
# ...

# %%
#saare hill ur conio wale column aa jaega
z.loc[['Hill','Onio']]
# Out:
#          RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# Surname
# Hill             2    15647311          608     Spain  Female   41       1
# Hill           900    15632210          657   Germany    Male   25       2
# Hill          1124    15596800          779   Germany    Male   33       1
# Hill          2113    15631201          472     Spain  Female   28       4
# Hill          2367    15623430          672    France    Male   34       9
# Hill          3904    15678129          643     Spain  Female   45       9
# Hill          4071    15611551          676     Spain    Male   48       1
# Hill          4116    15584505          580    France  Female   23       5
# Hill          4389    15801152          553     Spain  Female   39       1
# Hill          6557    15612207          840   Germany  Female   51       1
# Hill          7413    15631693          697    France    Male   36       7
# ...

# %%
t.loc[t['Age']>50]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 16           17    15737452        Romeo          653   Germany    Male   58
# 41           42    15738148       Clarke          465    France  Female   51
# 42           43    15687946      Osborne          556    France  Female   61
# 44           45    15684171      Bianchi          660     Spain  Female   61
# 58           59    15623944        T'ien          511     Spain  Female   66
# ...         ...         ...          ...          ...       ...     ...  ...
# 9936       9937    15653037        Parks          609    France    Male   77
# 9939       9940    15808971       Lajoie          693     Spain  Female   57
# 9948       9949    15735078    Onwughara          724   Germany  Female   53
# 9979       9980    15692664       Diribe          677    France  Female   58
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
#
# ...

# %%
#more than two condition
t.loc[(t['Age']>50)&(t['Gender']=='Male')]
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography Gender  Age  \
# 16           17    15737452       Romeo          653   Germany   Male   58
# 59           60    15804771   Velazquez          614    France   Male   51
# 63           64    15751208     Pirozzi          684     Spain   Male   56
# 70           71    15703793  Konovalova          738   Germany   Male   58
# 76           77    15614049          Hu          664    France   Male   55
# ...         ...         ...         ...          ...       ...    ...  ...
# 9879       9880    15669414      Pisano          486   Germany   Male   62
# 9909       9910    15773338    Endrizzi          739    France   Male   58
# 9910       9911    15784042          L?          624    France   Male   55
# 9917       9918    15755731       Davis          635   Germany   Male   53
# 9936       9937    15653037       Parks          609    France   Male   77
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#age>50,male inka creditscore
t.loc[(t['Age']>50)&(t['Gender']=='Male'),['CreditScore']]
# Out:
#       CreditScore
# 16            653
# 59            614
# 63            684
# 70            738
# 76            664
# ...           ...
# 9879          486
# 9909          739
# 9910          624
# 9917          635
# 9936          609
#
# [657 rows x 1 columns]

# %%
#copy t in t1 and concat
t1=t
s=pd.concat([t,t1])

# %%
print(t.head())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
#concat columns
s=pd.concat([t,t1],axis=1)
s
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619     France  Female   42
# 1             2    15647311       Hill          608      Spain  Female   41
# 2             3    15619304       Onio          502     France  Female   42
# 3             4    15701354       Boni          699     France  Female   39
# 4             5    15737888   Mitchell          850      Spain  Female   43
# ...         ...         ...        ...          ...        ...     ...  ...
# 9995       9996    15606229   Obijiaku          771     France    Male   39
# 9996       9997    15569892  Johnstone          516     France    Male   35
# 9997       9998    15584532        Liu          709     France  Female   36
# 9998       9999    15682355  Sabbatini          772    Germany    Male   42
# 9999      10000    15628319     Walker          792     France  Female   28
#
# ...

# %%
#by makinfg new row and adding
n = pd.DataFrame([{'Surname':'Jane', 'Age':25, 'Geography':'Madrid'}])
t = pd.concat([t, n], ignore_index=True)
t
# Out:
#        RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0            1.0  15634602.0  Hargrave        619.0    France  Female   42
# 1            2.0  15647311.0      Hill        608.0     Spain  Female   41
# 2            3.0  15619304.0      Onio        502.0    France  Female   42
# 3            4.0  15701354.0      Boni        699.0    France  Female   39
# 4            5.0  15737888.0  Mitchell        850.0     Spain  Female   43
# ...          ...         ...       ...          ...       ...     ...  ...
# 10001    10001.0         NaN       NaN          NaN    Madrid     NaN   25
# 10002    10001.0         NaN       NaN          NaN    Madrid     NaN   25
# 10003        NaN         NaN    Madrid          NaN       NaN     NaN   25
# 10004        NaN         NaN    Madrid          NaN       NaN     NaN   25
# 10005        NaN         NaN      Jane          NaN    Madrid     NaN   25
#
# ...

# %%
#x m t ka 2 column add kr k concat kr dia
x=t.head(2)
t=pd.concat([t,x])
t
# Out:
#     RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0         1.0  15634602.0  Hargrave        619.0    France  Female   42
# 1         2.0  15647311.0      Hill        608.0     Spain  Female   41
# 2         3.0  15619304.0      Onio        502.0    France  Female   42
# 3         4.0  15701354.0      Boni        699.0    France  Female   39
# 4         5.0  15737888.0  Mitchell        850.0     Spain  Female   43
# ..        ...         ...       ...          ...       ...     ...  ...
# 1         2.0  15647311.0      Hill        608.0     Spain  Female   41
# 0         1.0  15634602.0  Hargrave        619.0    France  Female   42
# 1         2.0  15647311.0      Hill        608.0     Spain  Female   41
# 0         1.0  15634602.0  Hargrave        619.0    France  Female   42
# 1         2.0  15647311.0      Hill        608.0     Spain  Female   41
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#concat using iloc
t.head()
z=t.iloc[3:5,0:2]
t=pd.concat([t,z])
t
# Out:
#     RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0         1.0  15634602.0  Hargrave        619.0    France  Female  42.0
# 1         2.0  15647311.0      Hill        608.0     Spain  Female  41.0
# 2         3.0  15619304.0      Onio        502.0    France  Female  42.0
# 3         4.0  15701354.0      Boni        699.0    France  Female  39.0
# 4         5.0  15737888.0  Mitchell        850.0     Spain  Female  43.0
# ..        ...         ...       ...          ...       ...     ...   ...
# 1         2.0  15647311.0       NaN          NaN       NaN     NaN   NaN
# 0         1.0  15634602.0       NaN          NaN       NaN     NaN   NaN
# 1         2.0  15647311.0       NaN          NaN       NaN     NaN   NaN
# 3         4.0  15701354.0       NaN          NaN       NaN     NaN   NaN
# 4         5.0  15737888.0       NaN          NaN       NaN     NaN   NaN
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#Append row of dataframe using iloc
t.head()
q=t.iloc[0:2,0:2]
q.head()
A=pd.DataFrame(data={'RowNumber':17,'CustomerId':78},index=[1])
A.head()
Q=pd.concat([t,A])
Q
# Out:
#     RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0         1.0  15634602.0  Hargrave        619.0    France  Female  42.0
# 1         2.0  15647311.0      Hill        608.0     Spain  Female  41.0
# 2         3.0  15619304.0      Onio        502.0    France  Female  42.0
# 3         4.0  15701354.0      Boni        699.0    France  Female  39.0
# 4         5.0  15737888.0  Mitchell        850.0     Spain  Female  43.0
# ..        ...         ...       ...          ...       ...     ...   ...
# 4         5.0  15737888.0       NaN          NaN       NaN     NaN   NaN
# 1        17.0        78.0       NaN          NaN       NaN     NaN   NaN
# 1        17.0        78.0       NaN          NaN       NaN     NaN   NaN
# 1        17.0        78.0       NaN          NaN       NaN     NaN   NaN
# 1        17.0        78.0       NaN          NaN       NaN     NaN   NaN
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...
